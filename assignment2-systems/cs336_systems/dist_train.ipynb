# %%
from IPython.display import display
from pathlib import Path
import sys
import timeit
import os
from contextlib import nullcontext

project_dir = Path(os.path.abspath('')).parent
project_path = project_dir.as_posix()
if project_path not in sys.path:
    sys.path.insert(0, project_path)
basics_path = (project_dir / "cs336-basics").as_posix()
if basics_path not in sys.path:
    sys.path.insert(0, basics_path)

import pandas as pd
import numpy as np
import torch
from tqdm import tqdm

# %load_ext autoreload
# %autoreload 2
from cs336_systems import dist_train

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### distributed_communication_single_node

# %%
df = pd.DataFrame(columns=["world_size", "data_size_MB", "time_seconds"])
for world_size in tqdm([1, 2, 4, 6]):
    for data_size in [1, 10, 100, 1000]:
        print("-" * 10, f"world_size={world_size}, data_size={data_size} MB", "-" * 10)
        t = dist_train.run_sum(world_size, data_size, device="cpu")
        df.loc[len(df)] = [world_size, data_size, t]
df
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# ---------- world_size=1, data_size=1 MB ----------
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# rank 0 data (before all-reduce,0.823): 1.0 MB, tensor([-2.3207, -0.0377,  0.0139,  0.0719,  2.3168]) ...
# rank 0 data (after all-reduce,0.824,0.001): 1.0 MB, tensor([-2.3207, -0.0377,  0.0139,  0.0719,  2.3168]) ...
# ---------- world_size=1, data_size=10 MB ----------
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# rank 0 data (before all-reduce,0.869): 10.0 MB, tensor([ 0.5962, -3.2291, -1.1815, -0.1357, -2.5871]) ...
# rank 0 data (after all-reduce,0.870,0.001): 10.0 MB, tensor([ 0.5962, -3.2291, -1.1815, -0.1357, -2.5871]) ...
# ---------- world_size=1, data_size=100 MB ----------
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# ...
